# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
img=np.zeros((800,800,3),dtype="uint8")
cv2.rectangle(img,(200,600),(600,400),(0,255,0),5)
cv2.rectangle(img,(250,570),(550,430),(0,255,0),5)
cv2.rectangle(img,(250,350),(400,400),(0,255,0),5)


 
cv2.circle(img,(400,500),60,(255,0,0),3)
cv2.circle(img,(400,500),40,(255,0,0),3)

font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'@mob_films_',(200,300),font,2,(0,255,0),6,cv2.LINE_AA)

cv2.line(img,(200,325),(650,325),(0,0,255),6)
plt.imshow(img)
plt.show()
