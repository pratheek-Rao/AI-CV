# %%
# !pip install scikit-learn
# !pip install matplotlib
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

np.random.seed(0)
X=np.random.rand(200,2)
k=5
kmeans=KMeans(n_clusters=k)
kmeans.fit(X)
cluster_centers=kmeans.cluster_centers_
labels=kmeans.labels_
plt.scatter(X[:,0],X[:,1],c=labels)
plt.scatter(cluster_centers[:,0],cluster_centers[:,1],marker='+',s=100,color='red')
plt.title(f'K-Means Clustering(k={k})')
plt.show()
# Out:
# Requirement already satisfied: scikit-learn in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in ./.local/lib/python3.9/site-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.5.0 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in ./.local/lib/python3.9/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: matplotlib in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in ./.local/lib/python3.9/site-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: zipp>=3.1.0 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# /home/student/.conda/envs/nmamit-4nm21ai051/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
